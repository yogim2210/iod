# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>
#
# # Statistics - Part 1

# %%
import numpy as np
import matplotlib.pyplot as plt
# get matplot to show charts inline
# %matplotlib inline

# %%
plt.pie(frequency)
# Out:
# ([<matplotlib.patches.Wedge at 0x1b16e20a160>,
#   <matplotlib.patches.Wedge at 0x1b16e20a640>,
#   <matplotlib.patches.Wedge at 0x1b16e20ab20>,
#   <matplotlib.patches.Wedge at 0x1b16e215040>],
#  [Text(0.8313245164615624, 0.7203468250294088, ''),
#   Text(-1.0801215852985862, 0.2081762737971575, ''),
#   Text(0.3597749159591659, -1.0395008464867046, ''),
#   Text(1.0395009643826039, -0.3597745753213204, '')])

# %%
# frequency of some observations using pie chart
labels = 'Developers', 'Data Engineers', 'Data Scientists', 'Business Analysts'
frequency = [15, 32, 12, 7]

fig1, ax1 = plt.subplots()

explode = (0, 0, 0, 0)  # modify this to "explode" only the 3rd slice (i.e. 'Data Scientists')
ax1.pie(frequency, 
        explode=explode, 
        labels=labels, 
        autopct='%1.1f%%',
        shadow=True, 
        startangle=90)

ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
# plot frequency of some observations using bar chart
objects = ('Python', 'C++', 'Java', 'Perl', 'Scala', 'Lisp')
y_pos = np.arange(len(objects))
performance = [10,8,6,4,2,1]
 
# Create a bar plot of performance for each object
plt.xticks(y_pos, objects)
plt.bar(y_pos, height=performance)

# Use ylabel and title to label the y axis and provide a title
# Out:
# <BarContainer object of 6 artists>

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2022 Institute of Data
#
#
# ---
#
#
#
# ---
